# %%
import pandas as pd	

import datetime as dt
import matplotlib.dates as mdates 

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Candidate-Democratic-Primary-New_York-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis Hillary Clinton: (New York) [Searches]
list_2_values = list(df[list_labels[2]]) #y_axis Bernie Sanders: (New York) [Searches]

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Candidate-Democratic-Primary-New_York-Trend')
plt.xlabel('Day')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Candidate-Democratic-Primary-New_York-Line.png', format='png') #saving as pngs atm
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Candidate-Democratic-Primary-United_States-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Candidate-Democratic-Primary-United_States-Trend.csv')
plt.xlabel('Day')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Candidate-Democratic-Primary-United_States-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Candidate-Presidential-California-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Candidate-Presidential-California-Trend.csv')
plt.xlabel('Day')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Candidate-Presidential-California-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Candidate-Presidential-Texas-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Candidate-Presidential-Texas-Trend.csv')
plt.xlabel('Day')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Candidate-Presidential-Texas-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Candidate-Presidential-United_States-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Candidate-Presidential-United_States-Trend.csv')
plt.xlabel('Day')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Candidate-Presidential-United_States-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Candidate-Republican-Primary-Florida-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 
list_3_values = list(df[list_labels[3]]) #y_axis 
list_4_values = list(df[list_labels[4]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])
plt.plot(x_axis,list_3_values,label=list_labels[3])
plt.plot(x_axis,list_4_values,label=list_labels[4])

#descriptive information
plt.title('Candidate-Republican-Primary-Florida-Trend.csv')
plt.xlabel('Day')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Candidate-Republican-Primary-Florida-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Candidate-Republican-Primary-United_States-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 
list_3_values = list(df[list_labels[3]]) #y_axis 
list_4_values = list(df[list_labels[4]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])
plt.plot(x_axis,list_3_values,label=list_labels[3])
plt.plot(x_axis,list_4_values,label=list_labels[4])

#descriptive information
plt.title('Candidate-Republican-Primary-United_States-Trend.csv')
plt.xlabel('Day')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Candidate-Republican-Primary-United_States-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Party-California-Trend.csv')

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Party-California-Trend.csv')
plt.xlabel('Week')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(25))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Party-California-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Party-Texas-Trend.csv')

df

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Party-Texas-Trend.csv')
plt.xlabel('Week')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(25))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Party-Texas-Line.png', format='png')
plt.close()

# %%
#data source access
df=pd.read_csv('../Trend_CSV/Party-United_States-Trend.csv')
df

#list setup
list_labels = list(df.columns.values.tolist())
list_x_values = list(df[list_labels[0]]) #x_axis Index [Dates]
list_1_values = list(df[list_labels[1]]) #y_axis 
list_2_values = list(df[list_labels[2]]) #y_axis 

#datetime converter
converted_dates = list(map(dt.datetime.strptime, list_x_values, len(list_x_values)*['%Y-%m-%d']))
x_axis = converted_dates

#chart setup
fig=plt.figure(figsize=(10, 5));
ax=plt.axes()

#plot(x data points, y data points, label)
plt.plot(x_axis,list_1_values,label=list_labels[1])
plt.plot(x_axis,list_2_values,label=list_labels[2])

#descriptive information
plt.title('Party-United_States-Trend.csv')
plt.xlabel('Week')
plt.ylabel('Interest over time')

#commands
plt.legend()
fig.autofmt_xdate()
ax.xaxis.set_major_locator(ticker.MultipleLocator(25))
#plt.show() #interferes with plt.savefig()

plt.savefig('../Line_Chart_PNG/Party-United_States-Line.png', format='png')
plt.close()
